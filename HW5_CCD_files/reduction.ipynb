# %% [markdown]
# !pip install ccdproc

# %%
from pathlib import Path

from astropy import units as u
from astropy.nddata import CCDData
from astropy.io import fits
from astropy.stats import mad_std

import aplpy
import aplpy.regions

import ccdproc as ccdp
from matplotlib import pyplot as plt
import numpy as np

#from convenience_functions import show_image

# %%
# !ls
# Out:
# Bias-001.fit.gz  Bias-013.fit.gz       Flat_V-1.fit.gz
# Bias-002.fit.gz  Bias-014.fit.gz       Flat_V-2.fit.gz
# Bias-003.fit.gz  Bias-015.fit.gz       Flat_V-3.fit.gz
# Bias-004.fit.gz  Bias-016.fit.gz       Flat_V-4.fit.gz
# Bias-005.fit.gz  Dark-1min-001.fit.gz  Flat_V-5.fit.gz
# Bias-006.fit.gz  Dark-1min-002.fit.gz  Flat_V-6.fit.gz
# Bias-007.fit.gz  Dark-1min-003.fit.gz  Flat_V-7.fit.gz
# Bias-008.fit.gz  Dark-1min-004.fit.gz  Flat_V-8.fit.gz
# Bias-009.fit.gz  Dark-1min-005.fit.gz  M39_V_1min-1.fit.gz
# Bias-010.fit.gz  Dark-1min-006.fit.gz  reduction.ipynb
# Bias-011.fit.gz  Dark-1min-007.fit.gz
# Bias-012.fit.gz  Dark-1min-008.fit.gz

# %%
image = fits.open('M39_V_1min-1.fit.gz')
fig = aplpy.FITSFigure(image)
fig.show_colorscale()

#fig.show_regions('test.reg')
# Out:
# WARNING: No WCS information found in header - using pixel coordinates [aplpy.header]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59051.791875 from DATE-OBS'. [astropy.wcs.wcs]
# INFO: Auto-setting vmin to  1.303e+03 [aplpy.core]
# INFO: Auto-setting vmax to  2.136e+03 [aplpy.core]
