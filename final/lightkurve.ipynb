# %%
import lightkurve as lk
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dqtau = lk.search_targetpixelfile('DM Tau', mission='K2')
#('DQ Tau', mission='K2', campaign=13, exptime='short')
dqtau
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime  target_name  distance
#                                   s                   arcsec
# --- -------------- ---- ------ ------- ------------- --------
#   0 K2 Campaign 13 2017     K2    1800 ktwo247047380      0.0

# %%
tpf = dqtau.download()
fcad = tpf[1]
fcad
# Out:
# KeplerTargetPixelFile Object (ID: 247047380)

# %%
len(tpf)
# Out:
# 3643

# %%
fcad = tpf[1000]

# %%
fcad.plot(aperture_mask=fcad.pipeline_mask)
# Out:
# <AxesSubplot:title={'center':'Target ID: 247047380, Cadence: 141947'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
fcad.plot(aperture_mask=fcad.pipeline_mask)
# Out:
# <AxesSubplot:title={'center':'Target ID: 247047380, Cadence: 141947'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
fcad.plot(aperture_mask=fcad.pipeline_mask)
# Out:
# <AxesSubplot:title={'center':'Target ID: 247047380, Cadence: 141947'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
fcad.plot(aperture_mask=fcad.pipeline_mask)
# Out:
# <AxesSubplot:title={'center':'Target ID: 247047380, Cadence: 141947'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
tpf.plot(aperture_mask=tpf.pipeline_mask);

# %%
custom_threshold_mask = tpf.create_threshold_mask(threshold=0.1)
custom_threshold_mask
# Out:
# array([[False, False, False, False, False, False, False, False, False,
#         False],
#        [False, False, False, False,  True,  True,  True, False, False,
#         False],
#        [False, False, False,  True,  True,  True,  True,  True,  True,
#         False],
#        [False, False,  True,  True,  True,  True,  True,  True,  True,
#         False],
#        [False, False,  True,  True,  True,  True,  True,  True,  True,
#         False],
#        [False, False, False,  True,  True,  True,  True,  True, False,
#         False],
#        [False, False, False,  True,  True,  True,  True,  True, False,
#         False],
#        [False, False, False,  True,  True,  True,  True,  True, False,
#         False],
#        [False, False, False, False,  True,  True, False, False, False,
#         False]])

# %%
ax = tpf.to_lightcurve(aperture_mask='pipeline').normalize().plot(label='pipeline', linewidth=2)
tpf.to_lightcurve(aperture_mask='threshold').normalize().plot(ax=ax, label='threshold', linewidth=2)
#tpf.to_lightcurve(aperture_mask='all').normalize().plot(ax=ax, label='all', linewidth=2)
#tpf.to_lightcurve(aperture_mask=custom_threshold_mask).normalize().plot(ax=ax, label='custom threshold', linewidth=2);
plt.savefig('dmtau_lc_aperture.png')

# %% [markdown]
# ### the aperture_mask is smaller than that of Kospal's paper. So what should I do?

# %%
lc = tpf.to_lightcurve(aperture_mask='all');

# %%
lc.plot?

# %%
lc.plot();
